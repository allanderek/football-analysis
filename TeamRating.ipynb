# %%
import pandas
from IPython.display import display, HTML
import urllib.request

# %%
class League(object):
    def __init__(self, league_short_title, fixtures_directory):
        self.title = fixtures_directory # Probably should have keyword argument for this with this as default.
        data_file_basename = league_short_title + ".csv"
        self.data_url = "http://www.football-data.co.uk/mmz4281/1415/" + data_file_basename
        self.data_file = "data/1415/" + data_file_basename
        self.fixtures_url = "http://www.bbc.co.uk/sport/football/" + fixtures_directory + "/fixtures"
        self.fixtures_file = "data/1415/" + league_short_title + "-fixtures.html"
    
    def retrieve_data_and_fixtures(self):
        urllib.request.urlretrieve(self.data_url, self.data_file)
        urllib.request.urlretrieve(self.fixtures_url, self.fixtures_file)
    
    def display_title(self):
        display(HTML("<h2>" + self.title + "</h2>"))

# %%
epl_league = League("E0", "premier-league")
leagues = [epl_league,
           League("E1", "championship"),
           League("E2", "league-one"),
           League("E3", "league-two"),
           League("SC0", "scottish-premiership"),
           # League("SC1", "scottish-championship") No shots data
           ]

# %%
for league in leagues:
    league.retrieve_data_and_fixtures()

# %%
# This is just hear so that I don't have to keep opening the notes file to remind myself of how the .csv data is presented.
with open('data/notes.txt', 'r') as notes_file:
    print(notes_file.read())
# Out:
# Notes for Football Data
#
# All data is in csv format, ready for use within standard spreadsheet applications. Please note that some abbreviations are no longer in use (in particular odds from specific bookmakers no longer used) and refer to data collected in earlier seasons. For a current list of what bookmakers are included in the dataset please visit http://www.football-data.co.uk/matches.php
#
# Key to results data:
#
# Div = League Division
# Date = Match Date (dd/mm/yy)
# HomeTeam = Home Team
# AwayTeam = Away Team
# FTHG = Full Time Home Team Goals
# FTAG = Full Time Away Team Goals
# FTR = Full Time Result (H=Home Win, D=Draw, A=Away Win)
# HTHG = Half Time Home Team Goals
# HTAG = Half Time Away Team Goals
# HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#
# Match Statistics (where available)
# Attendance = Crowd Attendance
# Referee = Match Referee
# HS = Home Team Shots
# AS = Away Team Shots
# HST = Home Team Shots on Target
# AST = Away Team Shots on Target
# HHW = Home Team Hit Woodwork
# AHW = Away Team Hit Woodwork
# HC = Home Team Corners
# AC = Away Team Corners
# HF = Home Team Fouls Committed
# AF = Away Team Fouls Committed
# HO = Home Team Offsides
# AO = Away Team Offsides
# HY = Home Team Yellow Cards
# AY = Away Team Yellow Cards
# HR = Home Team Red Cards
# AR = Away Team Red Cards
# HBP = Home Team Bookings Points (10 = yellow, 25 = red)
# ABP = Away Team Bookings Points (10 = yellow, 25 = red)
#
# Key to 1X2 (match) betting odds data:
#
# B365H = Bet365 home win odds
# B365D = Bet365 draw odds
# B365A = Bet365 away win odds
# BSH = Blue Square home win odds
# BSD = Blue Square draw odds
# BSA = Blue Square away win odds
# BWH = Bet&Win home win odds
# BWD = Bet&Win draw odds
# BWA = Bet&Win away win odds
# GBH = Gamebookers home win odds
# GBD = Gamebookers draw odds
# GBA = Gamebookers away win odds
# IWH = Interwetten home win odds
# IWD = Interwetten draw odds
# IWA = Interwetten away win odds
# LBH = Ladbrokes home win odds
# LBD = Ladbrokes draw odds
# LBA = Ladbrokes away win odds
# PSH = Pinnacle Sports home win odds
# PSD = Pinnacle Sports draw odds
# PSA = Pinnacle Sports away win odds
# SOH = Sporting Odds home win odds
# SOD = Sporting Odds draw odds
# SOA = Sporting Odds away win odds
# SBH = Sportingbet home win odds
# SBD = Sportingbet draw odds
# SBA = Sportingbet away win odds
# SJH = Stan James home win odds
# SJD = Stan James draw odds
# SJA = Stan James away win odds
# SYH = Stanleybet home win odds
# SYD = Stanleybet draw odds
# SYA = Stanleybet away win odds
# VCH = VC Bet home win odds
# VCD = VC Bet draw odds
# VCA = VC Bet away win odds
# WHH = William Hill home win odds
# WHD = William Hill draw odds
# WHA = William Hill away win odds
#
# Bb1X2 = Number of BetBrain bookmakers used to calculate match odds averages and maximums
# BbMxH = Betbrain maximum home win odds
# BbAvH = Betbrain average home win odds
# BbMxD = Betbrain maximum draw odds
# BbAvD = Betbrain average draw win odds
# BbMxA = Betbrain maximum away win odds
# BbAvA = Betbrain average away win odds
#
#
#
# Key to total goals betting odds:
#
# BbOU = Number of BetBrain bookmakers used to calculate over/under 2.5 goals (total goals) averages and maximums
# BbMx>2.5 = Betbrain maximum over 2.5 goals
# BbAv>2.5 = Betbrain average over 2.5 goals
# BbMx<2.5 = Betbrain maximum under 2.5 goals
# BbAv<2.5 = Betbrain average under 2.5 goals
#
# GB>2.5 = Gamebookers over 2.5 goals
# GB<2.5 = Gamebookers under 2.5 goals
# B365>2.5 = Bet365 over 2.5 goals
# B365<2.5 = Bet365 under 2.5 goals
#
#
# Key to Asian handicap betting odds:
#
# BbAH = Number of BetBrain bookmakers used to Asian handicap averages and maximums
# BbAHh = Betbrain size of handicap (home team)
# BbMxAHH = Betbrain maximum Asian handicap home team odds
# BbAvAHH = Betbrain average Asian handicap home team odds
# BbMxAHA = Betbrain maximum Asian handicap away team odds
# BbAvAHA = Betbrain average Asian handicap away team odds
#
# GBAHH = Gamebookers Asian handicap home team odds
# GBAHA = Gamebookers Asian handicap away team odds
# GBAH = Gamebookers size of handicap (home team)
# LBAHH = Ladbrokes Asian handicap home team odds
# LBAHA = Ladbrokes Asian handicap away team odds
# LBAH = Ladbrokes size of handicap (home team)
# B365AHH = Bet365 Asian handicap home team odds
# B365AHA = Bet365 Asian handicap away team odds
# B365AH = Bet365 size of handicap (home team)
#
# Football-Data would like to acknowledge the following sources which have been utilised in the compilation of Football-Data's results and odds files.
#
# Historical results:
# International Soccer Server - http://sunsite.tut.fi/rec/riku/soccer.html
# European Football - http://www.eurofootball.be/
# RSSSF Archive - http://www.rsssf.com/
#
# Current results (full time, half time)
# TBWSport - http://www.tbwsport.com
# Livescore- http://www.livescore.com
#
# Match statistics
# Sportinglife, ESPN Soccer, Bundesliga.de, Gazzetta.it and Football.fr
#
# Bookmakers betting odds
# Betbrain - http://www.betbrain.com
# Betbase - http://www.betbase.info
#
# Betting odds for weekend games are collected Friday afternoons, and on Tuesday afternoons for midweek games.
#
# Additional match statistics (corners, shots, bookings, referee etc.) for the 2000/01 and 2001/02 seasons for the English, Scottish and German leagues were provided by Sports.com (now under new ownership and no longer available).

# %%
def get_home_pdo(row):
    """ 1000*(goals for/shots on target for + (shots on target against – goals against)/shots on target against) """
    goals_for = row.FTHG
    shots_on_target_for = row.HST
    shooting_percentage = goals_for / shots_on_target_for if shots_on_target_for else 0.0
    shots_on_target_against = row.AST
    goals_against = row.FTAG
    saves = shots_on_target_against - goals_against
    # The save percentage is basically the same as the 1.0 - the away team's shot percentage
    # which is why this is 1.0 in the case that there were no away shots.
    save_percentage = saves / shots_on_target_against if shots_on_target_against else 1.0
    return (shooting_percentage + save_percentage) - 1
def get_away_pdo(row):
    return 0.0 - row.HomePDO
def add_pdo_columns(data_frame):
    data_frame['HomePDO'] = data_frame.apply(get_home_pdo, axis=1)
    data_frame['AwayPDO'] = data_frame.apply(get_away_pdo, axis=1)
def get_home_tsott(row):
    """Shots on target for/Total shots for + Shots off target against/Total shots against"""
    shots_on_target_for = row.HST
    shots_for = row.HS
    shots_for_target_ratio = shots_on_target_for / shots_for if shots_for else 0
    shots_against = row.AS
    shots_off_target_against = shots_against - row.AST
    # Similar to the PDO, this is basically 1.0 - the away team's shots_target_ratio which
    # is again why this is 1.0 if there were no away shots.
    shots_against_off_target_ratio = shots_off_target_against / shots_against if shots_against else 1.0
    return (shots_for_target_ratio + shots_against_off_target_ratio) - 1.0
def get_away_tsott(row):
    return 0.0 - row.HomeTSOTT
def add_tsott_columns(data_frame):
    data_frame['HomeTSOTT'] = data_frame.apply(get_home_tsott, axis=1)
    data_frame['AwayTSOTT'] = data_frame.apply(get_away_tsott, axis=1)
def get_home_tsr(row):
    """Shots on target for/Total shots for + Shots off target against/Total shots against.
       However to keep it normalised around zero, with a negative value meaning bad and a
       positive value meaning good. So we take 0.5 from the ratio and multiply by 2.
    """
    shots_for = row.HS
    shots_against = row.AS
    total_shots = shots_for + shots_against
    tsr = shots_for / total_shots if total_shots else 0.5
    return tsr
def get_away_tsr(row):
    return 1.0 - row.HomeTSR
def add_tsr_columns(data_frame):
    data_frame['HomeTSR'] = data_frame.apply(get_home_tsr, axis=1)
    data_frame['AwayTSR'] = data_frame.apply(get_away_tsr, axis=1)
def get_team_rating(pdo, tsott, tsr):
    """ Essentially tsr * tsott * pdo, but not weight equally, James Grayson gives it as:
        Rating = (0.5+(TSR-0.5)*0.732^0.5)*(1.0+(%TSOTt-1.0)*0.166^2)*(1000+(PDO-1000)*0.176^0.5)
        But we have normalised the three values to average at 0. Note that by doing this we really
        shouldn't multipy. Instead we will add, but we will add only 0.82 of tsr, 0.45 of tsott and
        0.4 of pdo because these appear to be the repeatable portions.
    """
    normalised_tsr = (tsr - 0.5) * 2.0
    rating = (0.82 * normalised_tsr) + (0.45 * tsott) + (0.4 * pdo)
    return rating

def get_home_team_rating(row):
    return get_team_rating(row.HomePDO, row.HomeTSOTT, row.HomeTSR)
def get_away_team_rating(row):
    return get_team_rating(row.AwayPDO, row.AwayTSOTT, row.AwayTSR)
def add_team_rating_columns(data_frame):
    data_frame['HomeTeamRating'] = data_frame.apply(get_home_team_rating, axis=1)
    data_frame['AwayTeamRating'] = data_frame.apply(get_away_team_rating, axis=1)
def add_team_rating_related_columns(data_frame):
    add_pdo_columns(data_frame)
    add_tsott_columns(data_frame)
    add_tsr_columns(data_frame)
    add_team_rating_columns(data_frame)
rating_fields = ['PDO', 'TSOTT', 'TSR', 'TeamRating']
home_rating_fields = ["Home" + f for f in rating_fields]
away_rating_fields = ["Away" + f for f in rating_fields]
goal_fields = ['FTHG', 'FTAG']
def get_team_averages(data_frame, team):
    home_team_data_frame = data_frame[data_frame.HomeTeam == team]
    home_mean_row = home_team_data_frame[home_rating_fields].mean()
    away_team_data_frame = data_frame[data_frame.AwayTeam == team]
    away_mean_row = away_team_data_frame[away_rating_fields].mean()
    return home_mean_row, away_mean_row
def get_full_data_frame(data_file):
    data_frame = pandas.read_csv(data_file)
    add_team_rating_related_columns(data_frame)
    return data_frame

# %%
for league in leagues:
    league.data_frame = get_full_data_frame(league.data_file)

# %%
data_frame = epl_league.data_frame
data_frame[['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST'] + home_rating_fields + away_rating_fields]
# Out:
#            HomeTeam        AwayTeam  FTHG  FTAG  HS  AS  HST  AST   HomePDO  \
# 0           Arsenal  Crystal Palace     2     1  14   4    6    2 -0.166667
# 1         Leicester         Everton     2     2  11  13    3    3  0.000000
# 2        Man United         Swansea     1     2  14   5    5    4 -0.300000
# 3               QPR            Hull     0     1  19  11    6    4 -0.250000
# 4             Stoke     Aston Villa     0     1  12   7    2    2 -0.500000
# 5         West Brom      Sunderland     2     2  10   7    5    2 -0.600000
# 6          West Ham       Tottenham     0     1  18  10    4    4 -0.250000
# 7         Liverpool     Southampton     2     1  12  12    5    6  0.233333
# 8         Newcastle        Man City     0     2  12  13    0    5 -0.400000
# 9           Burnley         Chelsea     1     3   9  11    2    3 -0.500000
# 10      Aston Villa       Newcastle     0     0   9  11    0    4  0.000000
# 11          Chelsea       Leicester     2     0  27   6   10    4  0.200000
# 12   Crystal Palace        West Ham     1     3   9  17    4    8 -0.125000
# 13          Everton         Arsenal     2     2   8  13    2    3  0.333333
# 14      Southampton       West Brom     0     0   8   8    2    2  0.000000
# 15          Swansea         Burnley     1     0  10  12    5    1  0.200000
# 16             Hull           Stoke     1     1   9  19    2    3  0.166667
# 17       Sunderland      Man United     1     1  11  10    3    3  0.000000
# 18        Tottenham             QPR     4     0  18   9    5    1  0.800000
# 19         Man City       Liverpool     3     1   9  11    4    3  0.416667
# 20          Burnley      Man United     0     0   9   7    3    2  0.000000
# 21          Everton         Chelsea     3     6  17  12    7    8 -0.321429
# 22         Man City           Stoke     0     1  16   7    2    2 -0.500000
# 23        Newcastle  Crystal Palace     3     3  18  12    4    7  0.321429
# 24              QPR      Sunderland     1     0  18  16    5    6  0.200000
# 25          Swansea       West Brom     3     0  15  16    8    2  0.375000
# 26         West Ham     Southampton     1     3   4  18    2    8  0.125000
# 27      Aston Villa            Hull     2     1  11   9    4    3  0.166667
# 28        Leicester         Arsenal     1     1   9  24    3    6  0.166667
# 29        Tottenham       Liverpool     0     3   7  17    1    8 -0.375000
# ..              ...             ...   ...   ...  ..  ..  ...  ...       ...
# 269            Hull      Sunderland     1     1  15   9    5    3 -0.133333
# 270     Southampton  Crystal Palace     1     0  23   9    3    3  0.333333
# 271       Liverpool         Burnley     2     0  20   9    8    1  0.250000
# 272        Man City       Leicester     2     0  22   6    9    2  0.222222
# 273       Newcastle      Man United     0     1   9  11    2    5 -0.200000
# 274             QPR         Arsenal     1     2  10  20    3    9  0.111111
# 275           Stoke         Everton     2     0  11  10    3    5  0.666667
# 276       Tottenham         Swansea     3     2  20  10    7    5  0.028571
# 277        West Ham         Chelsea     0     1  18  12    5    3 -0.333333
# 278             QPR       Tottenham     1     2  17  13    6    6 -0.166667
# 279         Arsenal        West Ham     3     0  19   7    9    1  0.333333
# 280         Burnley        Man City     1     0  10  21    4    5  0.250000
# 281  Crystal Palace             QPR     3     1  15  11    4    4  0.500000
# 282       Leicester            Hull     0     0  15  12    3    5  0.000000
# 283      Sunderland     Aston Villa     0     4  12  14    2    8 -0.500000
# 284       West Brom           Stoke     1     0  14   9    5    2  0.200000
# 285         Chelsea     Southampton     1     1  22  12    7    5 -0.057143
# 286         Everton       Newcastle     3     0  15  12    9    4  0.333333
# 287      Man United       Tottenham     3     0  11   5    3    1  1.000000
# 288         Swansea       Liverpool     0     1  10  16    3    5 -0.200000
# 289     Aston Villa         Swansea     0     1  12   9    3    6 -0.166667
# 290        Man City       West Brom     3     0  43   3   16    0  0.187500
# 291       Newcastle         Arsenal     1     2  16   7    4    3 -0.416667
# 292     Southampton         Burnley     2     0  20  15    3    3  0.666667
# 293           Stoke  Crystal Palace     1     2  17  12    4    3 -0.416667
# 294       Tottenham       Leicester     4     3  10  14    4    5  0.400000
# 295        West Ham      Sunderland     1     0  15   7    4    3  0.250000
# 296            Hull         Chelsea     2     3  19   8    8    3 -0.750000
# 297       Liverpool      Man United     1     2   7   6    1    4  0.500000
# 298             QPR         Everton     1     2  14   8    1    3  0.333333
#
#      HomeTSOTT   HomeTSR  HomeTeamRating   AwayPDO  AwayTSOTT   AwayTSR  \
# 0    -0.071429  0.777778        0.356746  0.166667   0.071429  0.222222
# 1     0.041958  0.458333       -0.049452  0.000000  -0.041958  0.541667
# 2    -0.442857  0.736842        0.069135  0.300000   0.442857  0.263158
# 3    -0.047847  0.633333        0.097136  0.250000   0.047847  0.366667
# 4    -0.119048  0.631579       -0.037782  0.500000   0.119048  0.368421
# 5     0.214286  0.588235        0.001134  0.600000  -0.214286  0.411765
# 6    -0.177778  0.642857        0.054286  0.250000   0.177778  0.357143
# 7    -0.083333  0.500000        0.055833 -0.233333   0.083333  0.500000
# 8    -0.384615  0.480000       -0.365877  0.400000   0.384615  0.520000
# 9    -0.050505  0.450000       -0.304727  0.500000   0.050505  0.550000
# 291  -0.178571  0.695652        0.073846  0.416667   0.178571  0.304348
# 292  -0.050000  0.571429        0.361310 -0.666667   0.050000  0.428571
# 293  -0.014706  0.586207       -0.031905  0.416667   0.014706  0.413793
# 294   0.042857  0.416667        0.042619 -0.400000  -0.042857  0.583333
# 295  -0.161905  0.681818        0.325325 -0.250000   0.161905  0.318182
# 296   0.046053  0.703704        0.054798  0.750000  -0.046053  0.296296
# 297  -0.523810  0.538462        0.027363 -0.500000   0.523810  0.461538
# 298  -0.303571  0.636364        0.220363 -0.333333   0.303571  0.363636
#
#      AwayTeamRating
# 0         -0.356746
# 1          0.049452
# 2         -0.069135
# 3         -0.097136
# 4          0.037782
# 5         -0.001134
# 6         -0.054286
# 7         -0.055833
# 8          0.365877
# 9          0.304727
# 10         0.245636
# 11        -0.468485
# 12         0.314072
# 13         0.053251
# 14         0.000000
# 15        -0.192955
# 16         0.197243
# 17        -0.026775
# 18        -0.668333
# 19        -0.161939
# 20        -0.123929
# 21         0.101898
# 22        -0.048548
# 23        -0.130071
# 24        -0.084485
# 25        -0.307298
# 26         0.446818
# 27        -0.162303
# 28         0.268561
# 29         0.639146
# ..              ...
# 269       -0.151667
# 270       -0.400779
# 271       -0.541034
# 272       -0.591551
# 273        0.266545
# 274        0.296389
# 275       -0.203442
# 276       -0.217262
# 277       -0.043167
# 278        0.006202
# 279       -0.660667
# 280        0.118111
# 281       -0.282517
# 282        0.006389
# 283        0.445220
# 284       -0.318975
# 285       -0.174001
# 286       -0.344444
# 287       -0.740227
# 288        0.274856
# 289        0.137024
# 290       -0.955485
# 291       -0.073846
# 292       -0.361310
# 293        0.031905
# 294       -0.042619
# 295       -0.325325
# 296       -0.054798
# 297       -0.027363
# 298       -0.220363
#
# [299 rows x 16 columns]

# %%
def compare_match_teams(data_frame, team1, team2):
    home_team_data_frame = data_frame[data_frame.HomeTeam == team1]
    home_mean_row = home_team_data_frame[home_rating_fields + goal_fields].mean()
    away_team_data_frame = data_frame[data_frame.AwayTeam == team2]
    away_mean_row = away_team_data_frame[away_rating_fields + goal_fields].mean()
    return home_mean_row, away_mean_row

# %%
def compare_matches(matches, data_frame):
    for home, away in matches:
        home_stats, away_stats = compare_match_teams(data_frame, home, away)
        for rating_field in rating_fields:
            home_rating_field = "Home" + rating_field
            home_stats[rating_field] = home_stats[home_rating_field]
            away_rating_field = "Away" + rating_field
            away_stats[rating_field] = away_stats[away_rating_field]

        home_stats['Goals For'] = home_stats['FTHG']
        home_stats['Goals Against'] = home_stats['FTAG']
        away_stats['Goals For'] = away_stats['FTAG']
        away_stats['Goals Against'] = away_stats['FTHG']

        goal_fields = ['Goals For', 'Goals Against']
        return_data_frame = pandas.DataFrame()
        return_data_frame[home] = home_stats[rating_fields + goal_fields]
        return_data_frame[away] = away_stats[rating_fields + goal_fields]
        display(return_data_frame)

# %%
from bs4 import BeautifulSoup

# %%
team_aliases = {'Dundee Utd' : 'Dundee United',
                'Inverness CT' : 'Inverness C',
                'Partick Thistle' : 'Partick',
                'Man Utd' : 'Man United',
                'Sheff Wed' : 'Sheffield Weds',
                'Nottm Forest' : "Nott'm Forest",
                'Sheff Utd' : 'Sheffield United',
                'MK Dons' : 'Milton Keynes Dons',
                'Fleetwood' : 'Fleetwood Town',
                'Peterborough' : 'Peterboro',
                'Crawley' : 'Crawley Town'
               }
def alias_team(team):
    return team_aliases.get(team, team)

def get_match_teams(match_details):
    home_team_span = match_details.find('span', class_='team-home teams')
    home_team = home_team_span.a.contents[0]
    away_team_span = match_details.find('span', class_='team-away teams')
    away_team = away_team_span.a.contents[0]
    return (alias_team(home_team), alias_team(away_team))
    
def compare_fixtures(data_frame, fixtures_page):
    soup = BeautifulSoup(open(fixtures_page, encoding='utf-8'))
    
    match_details_list = soup.find_all('td', class_='match-details')
    matches = [get_match_teams(md) for md in match_details_list]
    compare_matches(matches[0:12], data_frame)

# %%
team_aliases = {'Dundee Utd': 'Dundee United',
                'Inverness CT': 'Inverness C',
                'Partick Thistle': 'Partick',
                'Man Utd': 'Man United',
                'Sheff Wed': 'Sheffield Weds',
                'Nottm Forest': "Nott'm Forest",
                'Sheff Utd': 'Sheffield United',
                'MK Dons': 'Milton Keynes Dons',
                'Fleetwood': 'Fleetwood Town',
                'Peterborough': 'Peterboro',
                'Crawley': 'Crawley Town',
                'Newport': 'Newport County',
                'Dag & Red' : 'Dag and Red',
                'Oxford Utd': 'Oxford',
                'Wimbledon': 'AFC Wimbledon'
               }

# %%
for league in leagues:
    league.display_title()
    compare_fixtures(league.data_frame, league.fixtures_file)
# Out:
# <h2>premier-league</h2>
#                 Arsenal  Liverpool
# PDO            0.119035   0.142602
# TSOTT          0.025672   0.068815
# TSR            0.679668   0.518310
# TeamRating     0.353822   0.118036
# Goals For      2.357143   1.357143
# Goals Against  0.785714   1.142857
#                 Everton  Southampton
# PDO           -0.049150     0.007653
# TSOTT          0.092011     0.037251
# TSR            0.536751     0.529412
# TeamRating     0.082017     0.068060
# Goals For      1.571429     1.071429
# Goals Against  1.285714     0.785714
#                Leicester  West Ham
# PDO            -0.148718 -0.019615
# TSOTT          -0.019215 -0.023019
# TSR             0.522468  0.407108
# TeamRating     -0.031287 -0.170548
# Goals For       1.000000  1.285714
# Goals Against   1.307692  1.571429
#                Man United  Aston Villa
# PDO              0.186614    -0.100476
# TSOTT           -0.046620    -0.016928
# TSR              0.630672     0.433446
# TeamRating       0.267969    -0.156956
# Goals For        2.200000     0.533333
# Goals Against    0.666667     1.333333
#                 Swansea      Hull
# PDO            0.022157 -0.059418
# TSOTT          0.031979  0.033322
# TSR            0.509992  0.347417
# TeamRating     0.039640 -0.259008
# Goals For      1.266667  0.733333
# Goals Against  1.066667  1.333333
#                West Brom       QPR
# PDO            -0.011270 -0.177041
# TSOTT          -0.046774 -0.109283
# TSR             0.533826  0.414656
# TeamRating      0.029919 -0.259957
# Goals For       1.200000  0.714286
# Goals Against   1.266667  2.285714
#                 Chelsea     Stoke
# PDO            0.159694 -0.093333
# TeamRating             0.166973 -0.331700
# Goals For              1.526316  0.842105
# Goals Against          0.947368  2.263158
#                Fleetwood Town   Preston
# PDO                  0.036007  0.050992
# TSOTT                0.059588  0.153712
# TSR                  0.499815  0.564291
# TeamRating           0.040915  0.195005
# Goals For            1.105263  1.500000
# Goals Against        1.052632  0.777778
#                Bradford  Chesterfield
# PDO           -0.135400     -0.017504
# TSOTT         -0.015908     -0.017985
# TSR            0.595446      0.518373
# TeamRating     0.095213      0.015037
# Goals For      1.277778      1.111111
# Goals Against  1.277778      1.388889
#                Coventry  Leyton Orient
# PDO           -0.085673       0.050854
# TSOTT          0.009031       0.009719
# TSR            0.524670       0.474048
# TeamRating     0.010254      -0.017847
# Goals For      1.157895       1.333333
# Goals Against  1.473684       1.388889
# <h2>league-two</h2>
#                Accrington  Newport County
# PDO              0.004302       -0.034837
# TSOTT           -0.008513       -0.044801
# TSR              0.495474        0.475706
# TeamRating      -0.009533       -0.073937
# Goals For        1.368421        0.894737
# Goals Against    1.368421        1.315789
#                    Bury  Southend
# PDO            0.075336 -0.104302
# TSOTT          0.035592  0.002328
# TSR            0.576422  0.567710
# TeamRating     0.171482  0.070372
# Goals For      1.526316  1.315789
# Goals Against  0.894737  1.368421
#                Cheltenham  Plymouth
# PDO              0.050125 -0.057456
# TSOTT           -0.013077 -0.062997
# TSR              0.457175  0.476416
# TeamRating      -0.056068 -0.090009
# Goals For        1.000000  0.789474
# Goals Against    1.263158  1.000000
#                Dag and Red   Wycombe
# PDO               0.196763  0.057206
# TSOTT            -0.152862  0.078669
# TSR               0.452120  0.518973
# TeamRating       -0.068606  0.089399
# Goals For         1.157895  1.736842
# Goals Against     1.315789  0.894737
#                  Exeter  Morecambe
# PDO           -0.188800  -0.047744
# TSOTT          0.060972   0.203362
# TSR            0.498586   0.399681
# TeamRating    -0.050401  -0.092108
# Goals For      1.315789   1.157895
# Goals Against  1.368421   1.052632
#                Hartlepool  Cambridge
# PDO             -0.100627   0.149311
# TSOTT           -0.098024   0.004597
# TSR              0.480726   0.419713
# TeamRating      -0.115971  -0.069877
# Goals For        0.894737   1.263158
# Goals Against    1.368421   1.368421
#                Mansfield      York
# PDO             0.087135 -0.002966
# TSOTT          -0.013566  0.013784
# TSR             0.525778  0.500346
# TeamRating      0.071025  0.005584
# Goals For       1.105263  1.315789
# Goals Against   0.894737  1.421053
#                Northampton     Luton
# PDO               0.127015 -0.080189
# TSOTT            -0.008599  0.053170
# TSR               0.566863  0.450094
# TeamRating        0.156592 -0.089995
# Goals For         1.736842  0.789474
# Goals Against     1.157895  1.157895
#                  Oxford  Carlisle
# PDO           -0.143734 -0.056454
# TSOTT         -0.011012  0.024972
# TSR            0.616607  0.410644
# TeamRating     0.128787 -0.157888
# Goals For      1.157895  0.947368
# Goals Against  1.157895  1.578947
#                Portsmouth  Shrewsbury
# PDO              0.144737   -0.034545
# TSOTT            0.053565   -0.064548
# TSR              0.544625    0.588146
# TeamRating       0.155184    0.101695
# Goals For        1.631579    1.052632
# Goals Against    0.947368    1.000000
#                Tranmere  AFC Wimbledon
# PDO           -0.090476       0.009080
# TSOTT         -0.003211      -0.059320
# TSR            0.552347       0.418429
# TeamRating     0.048214      -0.156839
# Goals For      1.315789       0.947368
# Goals Against  1.473684       1.421053
#                  Burton  Stevenage
# PDO            0.191173  -0.040226
# TSOTT          0.002490  -0.006152
# TSR            0.601302   0.474322
# TeamRating     0.243724  -0.060971
# Goals For      1.473684   1.105263
# Goals Against  0.526316   1.368421
# <h2>scottish-premiership</h2>
#                St Mirren    Celtic
# PDO            -0.178730  0.216209
# TSOTT          -0.129778  0.067565
# TSR             0.530360  0.636726
# TeamRating     -0.080102  0.341119
# Goals For       0.533333  1.923077
# Goals Against   1.533333  0.538462
#                Aberdeen   Partick
# PDO            0.171944 -0.168707
# TSOTT         -0.104065 -0.070348
# TSR            0.668864  0.476754
# TeamRating     0.298885 -0.137263
# Goals For      2.142857  0.928571
# Goals Against  0.928571  1.285714
#                Dundee United  Ross County
# PDO                 0.029138     0.013535
# TSOTT               0.071830    -0.023816
# TSR                 0.519946     0.391799
# TeamRating          0.076690    -0.182752
# Goals For           1.857143     1.133333
# Goals Against       1.071429     1.933333
#                Hamilton  St Johnstone
# PDO            0.066227      0.017169
# TSOTT         -0.000533     -0.094454
# TSR            0.568574      0.394307
# TeamRating     0.138713     -0.208973
# Goals For      1.666667      0.733333
# Goals Against  1.200000      1.000000
#                Inverness C    Dundee
# PDO              -0.085913  0.079592
# TSOTT             0.077790  0.150060
# TSR               0.635914  0.411062
# TeamRating        0.223539 -0.046494
# Goals For         1.500000  1.428571
# Goals Against     1.000000  1.428571
#                Kilmarnock  Motherwell
# PDO              0.015623    0.006291
# TSOTT            0.009814   -0.082600
# TSR              0.527178    0.266922
# TeamRating       0.055238   -0.416901
# Goals For        1.285714    0.800000
# Goals Against    1.285714    2.333333
#                Motherwell  St Mirren
# PDO             -0.053201  -0.078110
# TSOTT            0.091927  -0.058079
# TSR              0.409768   0.423465
# TeamRating      -0.127893  -0.182897
# Goals For        0.933333   0.933333
# Goals Against    1.266667   1.733333
#                Ross County  St Johnstone
# PDO              -0.132619      0.017169
# TSOTT             0.037178     -0.094454
# TSR               0.481324      0.394307
# TeamRating       -0.066947     -0.208973
# Goals For         1.066667      0.733333
# Goals Against     1.733333      1.000000
#                Aberdeen  Inverness C
# PDO            0.171944    -0.051746
# TSOTT         -0.104065     0.100222
# TSR            0.668864     0.535667
# TeamRating     0.298885     0.082896
# Goals For      2.142857     1.400000
# Goals Against  0.928571     1.066667
#                  Celtic   Partick
# PDO            0.047735 -0.168707
# TSOTT          0.113839 -0.070348
# TSR            0.745613  0.476754
# TeamRating     0.473127 -0.137263
# Goals For      2.266667  0.928571
# Goals Against  0.466667  1.285714
#                  Dundee  Dundee United
# PDO            0.001190       0.042517
# TSOTT         -0.070471      -0.058728
# TSR            0.556025       0.484490
# TeamRating     0.060645      -0.034856
# Goals For      1.333333       1.642857
# Goals Against  1.333333       1.857143
#                Inverness C    Celtic
# PDO              -0.085913  0.216209
# TSOTT             0.077790  0.067565
# TSR               0.635914  0.636726
# TeamRating        0.223539  0.341119
# Goals For         1.500000  1.923077
# Goals Against     1.000000  0.538462

# %%
def display_recent_matches(data_frame, n=10):
    match_fields = (['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST', 'HR', 'AR'] + 
                    home_rating_fields + away_rating_fields)
    selected_data = data_frame[match_fields].tail(n=n)
    reversed_data_frame = selected_data.iloc[::-1]
    # Partly just to remind myself how to do this
    reversed_data_frame = reversed_data_frame.rename(columns={'HS': 'HomeShots', 'AS': 'AwayShots',
                                                              'FTHG': 'HomeGoals', 'FTAG': 'AwayGoals'})
    return reversed_data_frame

# %%
for league in leagues:
    league.display_title()
    display(display_recent_matches(league.data_frame, n=12))
# Out:
# <h2>premier-league</h2>
#         HomeTeam        AwayTeam  HomeGoals  AwayGoals  HomeShots  AwayShots  \
# 298          QPR         Everton          1          2         14          8
# 297    Liverpool      Man United          1          2          7          6
# 296         Hull         Chelsea          2          3         19          8
# 295     West Ham      Sunderland          1          0         15          7
# 294    Tottenham       Leicester          4          3         10         14
# 293        Stoke  Crystal Palace          1          2         17         12
# 292  Southampton         Burnley          2          0         20         15
# 291    Newcastle         Arsenal          1          2         16          7
# 290     Man City       West Brom          3          0         43          3
# 289  Aston Villa         Swansea          0          1         12          9
# 288      Swansea       Liverpool          0          1         10         16
# 287   Man United       Tottenham          3          0         11          5
#
#      HST  AST  HR  AR   HomePDO  HomeTSOTT   HomeTSR  HomeTeamRating  \
# 298    1    3   0   0  0.333333  -0.303571  0.636364        0.220363
# 297    1    4   1   0  0.500000  -0.523810  0.538462        0.027363
# 296    8    3   0   0 -0.750000   0.046053  0.703704        0.054798
# 295    4    3   0   0  0.250000  -0.161905  0.681818        0.325325
# 294    4    5   0   0  0.400000   0.042857  0.416667        0.042619
# 293    4    3   0   0 -0.416667  -0.014706  0.586207       -0.031905
# 292    3    3   0   0  0.666667  -0.050000  0.571429        0.361310
# 291    4    3   0   0 -0.416667  -0.178571  0.695652        0.073846
# 290   16    0   0   1  0.187500   0.372093  0.934783        0.955485
# 289    3    6   0   0 -0.166667  -0.416667  0.571429       -0.137024
# 288    3    5   0   0 -0.200000  -0.012500  0.384615       -0.274856
# 287    3    1   0   0  1.000000   0.072727  0.687500        0.740227
#
#       AwayPDO  AwayTSOTT   AwayTSR  AwayTeamRating
# 298 -0.333333   0.303571  0.363636       -0.220363
# 297 -0.500000   0.523810  0.461538       -0.027363
# 296  0.750000  -0.046053  0.296296       -0.054798
# 295 -0.250000   0.161905  0.318182       -0.325325
# 294 -0.400000  -0.042857  0.583333       -0.042619
# 293  0.416667   0.014706  0.413793        0.031905
# 292 -0.666667   0.050000  0.428571       -0.361310
# 291  0.416667   0.178571  0.304348       -0.073846
# 290 -0.187500  -0.372093  0.065217       -0.955485
# 289  0.166667   0.416667  0.428571        0.137024
# 288  0.200000   0.012500  0.615385        0.274856
# 287 -1.000000  -0.072727  0.312500       -0.740227
# <h2>championship</h2>
#          HomeTeam        AwayTeam  HomeGoals  AwayGoals  HomeShots  AwayShots  \
# 466         Wigan          Bolton          1          1         22          9
# 465       Watford         Ipswich          0          1          9         10
# 464     Rotherham  Sheffield Weds          2          3          9         15
# 463       Norwich   Nott'm Forest          3          1         20         10
# 462  Huddersfield          Fulham          0          2         31         10
# 461      Charlton         Reading          3          2         14         16
# 460       Cardiff      Birmingham          2          0         16          4
# 459     Brentford        Millwall          2          2         24         10
# 458   Bournemouth   Middlesbrough          3          0         17          3
# 457     Blackpool           Leeds          1          1         19         11
# 456     Blackburn        Brighton          0          1         16         10
# 455        Wolves           Derby          2          0         10         19
#
#      HST  AST  HR  AR   HomePDO  HomeTSOTT   HomeTSR  HomeTeamRating  \
# 466    8    3   0   0 -0.208333   0.030303  0.709677        0.274174
# 465    0    3   0   0 -0.333333  -0.300000  0.473684       -0.311491
# 464    4    6   0   0  0.000000   0.044444  0.375000       -0.185000
# 463    6    6   0   0  0.333333  -0.300000  0.666667        0.271667
# 462   13    3   0   1 -0.666667   0.119355  0.756098        0.207043
# 461    8    4   0   1 -0.125000   0.321429  0.466667        0.039976
# 460    4    1   0   0  0.500000   0.000000  0.800000        0.692000
# 459    8    4   0   0 -0.250000  -0.066667  0.705882        0.207647
# 458    7    0   0   0  0.428571   0.411765  0.850000        0.930723
# 457    6    3   0   0 -0.166667   0.043062  0.633333        0.171378
# 456    7    1   0   0 -1.000000   0.337500  0.615385       -0.058894
# 455    3    8   0   0  0.666667  -0.121053  0.344828       -0.042290
#
#       AwayPDO  AwayTSOTT   AwayTSR  AwayTeamRating
# 466  0.208333  -0.030303  0.290323       -0.274174
# 465  0.333333   0.300000  0.526316        0.311491
# 464  0.000000  -0.044444  0.625000        0.185000
# 463 -0.333333   0.300000  0.333333       -0.271667
# 462  0.666667  -0.119355  0.243902       -0.207043
# 461  0.125000  -0.321429  0.533333       -0.039976
# 460 -0.500000   0.000000  0.200000       -0.692000
# 459  0.250000   0.066667  0.294118       -0.207647
# 458 -0.428571  -0.411765  0.150000       -0.930723
# 457  0.166667  -0.043062  0.366667       -0.171378
# 456  1.000000  -0.337500  0.384615        0.058894
# 455 -0.666667   0.121053  0.655172        0.042290
# <h2>league-one</h2>
#                HomeTeam        AwayTeam  HomeGoals  AwayGoals  HomeShots  \
# 450    Sheffield United      Scunthorpe          4          0          9
# 449              Oldham        Rochdale          3          0         13
# 448    Sheffield United       Port Vale          1          0         12
# 447            Rochdale      Scunthorpe          3          1         11
# 446           Peterboro    Chesterfield          1          0          8
# 445  Milton Keynes Dons    Notts County          4          1         22
# 444          Gillingham      Colchester          2          2         11
# 443               Crewe          Oldham          0          1          9
# 442        Crawley Town   Leyton Orient          1          0          8
# 441            Coventry       Doncaster          1          3          8
# 440            Bradford  Fleetwood Town          2          2          8
# 439            Barnsley         Preston          1          1          8
#
#      AwayShots  HST  AST  HR  AR   HomePDO  HomeTSOTT   HomeTSR  \
# 450          4    6    0   0   1  0.666667   0.666667  0.692308
# 449          9    7    4   0   0  0.428571   0.094017  0.590909
# 448         11    6    3   0   1  0.166667   0.227273  0.521739
# 447          7    4    1   0   0 -0.250000   0.220779  0.611111
# 446         17    4    6   1   0  0.250000   0.147059  0.320000
# 445          8   16    5   0   0  0.050000   0.102273  0.733333
# 444         10    6    5   0   1 -0.066667   0.045455  0.523810
# 443         10    3    4   0   0 -0.250000  -0.066667  0.473684
# 442         18    2    9   0   0  0.500000  -0.250000  0.307692
# 441         13    5    6   0   0 -0.300000   0.163462  0.380952
# 440          7    5    3   0   0 -0.266667   0.196429  0.533333
# 439          8    1    6   0   0  0.833333  -0.625000  0.500000
#
#      HomeTeamRating   AwayPDO  AwayTSOTT   AwayTSR  AwayTeamRating
# 450        0.882051 -0.666667  -0.666667  0.307692       -0.882051
# 449        0.362827 -0.428571  -0.094017  0.409091       -0.362827
# 448        0.204592 -0.166667  -0.227273  0.478261       -0.204592
# 447        0.181573  0.250000  -0.220779  0.388889       -0.181573
# 446       -0.129024 -0.250000  -0.147059  0.680000        0.129024
# 445        0.448689 -0.050000  -0.102273  0.266667       -0.448689
# 444        0.032835  0.066667  -0.045455  0.476190       -0.032835
# 443       -0.173158  0.250000   0.066667  0.526316        0.173158
# 442       -0.227885 -0.500000   0.250000  0.692308        0.227885
# 441       -0.241680  0.300000  -0.163462  0.619048        0.241680
# 440        0.036393  0.266667  -0.196429  0.466667       -0.036393
# 439        0.052083 -0.833333   0.625000  0.500000       -0.052083
# <h2>league-two</h2>
#           HomeTeam        AwayTeam  HomeGoals  AwayGoals  HomeShots  \
# 455          Luton         Wycombe          2          3         15
# 454       Tranmere          Burton          1          4         12
# 453      Stevenage     Dag and Red          0          1          7
# 452       Southend       Cambridge          0          0         12
# 451     Shrewsbury          Oxford          2          0          5
# 450       Plymouth  Newport County          0          0          9
# 449     Hartlepool       Mansfield          1          0          7
# 448     Cheltenham          Exeter          1          2          9
# 447       Carlisle       Morecambe          1          1         13
# 446           Bury     Northampton          2          1          6
# 445  AFC Wimbledon      Portsmouth          1          0         10
# 444     Accrington            York          2          2          9
#
#      AwayShots  HST  AST  HR  AR   HomePDO  HomeTSOTT   HomeTSR  \
# 455         15    4    7   0   0  0.071429  -0.200000  0.500000
# 454          6    5    5   0   0 -0.600000  -0.416667  0.666667
# 453          4    1    2   0   0 -0.500000  -0.357143  0.636364
# 452          7    3    2   0   0  0.000000  -0.035714  0.631579
# 451         12    3    4   1   0  0.666667   0.266667  0.294118
# 450          7    3    2   0   0  0.000000   0.047619  0.562500
# 449          6    2    4   0   1  0.500000  -0.380952  0.538462
# 448          8    1    4   0   0  0.500000  -0.388889  0.529412
# 447         12    2    3   0   0  0.166667  -0.096154  0.520000
# 446         11    3    4   1   0  0.416667   0.136364  0.352941
# 445          9    6    5   0   0  0.166667   0.044444  0.526316
# 444         19    3    6   0   0  0.333333   0.017544  0.321429
#
#      HomeTeamRating   AwayPDO  AwayTSOTT   AwayTSR  AwayTeamRating
