# %% [markdown]
# This aims to be a simple notebook exploring the difference between a team's performance when at home and when away. We begin by running the team rating notebook. I think there are possibly other ways to do this which might be better, for example it would be good to import the other notebook and hence be able to refer to names using `TeamRating.leagues` for example. This might be possible doing [this](http://nbviewer.ipython.org/github/adrn/ipython/blob/2.x/examples/Notebook/Importing%20Notebooks.ipynb). I'm not sure why but that does not seem to be included by default by ipython.

# %%
# %run 'TeamRating.ipynb'
# Out:
# Notes for Football Data
#
# All data is in csv format, ready for use within standard spreadsheet applications. Please note that some abbreviations are no longer in use (in particular odds from specific bookmakers no longer used) and refer to data collected in earlier seasons. For a current list of what bookmakers are included in the dataset please visit http://www.football-data.co.uk/matches.php
#
# Key to results data:
#
# Div = League Division
# Date = Match Date (dd/mm/yy)
# HomeTeam = Home Team
# AwayTeam = Away Team
# FTHG = Full Time Home Team Goals
# FTAG = Full Time Away Team Goals
# FTR = Full Time Result (H=Home Win, D=Draw, A=Away Win)
# HTHG = Half Time Home Team Goals
# HTAG = Half Time Away Team Goals
# HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#
# Match Statistics (where available)
# Attendance = Crowd Attendance
# Referee = Match Referee
# HS = Home Team Shots
# AS = Away Team Shots
# HST = Home Team Shots on Target
# AST = Away Team Shots on Target
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plot

# %%
plot.scatter([1,2,3,4], [4,5,6,7])

# %%
def scatter_home_away(data_frame, team, column):    
    home_team_data_frame = data_frame[data_frame.HomeTeam == team]
    home_mean_row = home_team_data_frame[['Home' + column]].mean()
    away_team_data_frame = data_frame[data_frame.AwayTeam == team]
    away_mean_row = away_team_data_frame[['Away' + column]].mean()
    plot.scatter(home_mean_row, away_mean_row)
for team in ['Arsenal', 'Liverpool']:
    scatter_home_away(epl_league.data_frame, team, 'PDO')
